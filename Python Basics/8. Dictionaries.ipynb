# %%
x = {"std1" : "Deepu", "std2" : "ammu", "std3" : "kitti", "std4" : "Dolly", "std5" : "sai"}

print(x)
# Out:
# {'std1': 'Deepu', 'std2': 'ammu', 'std3': 'kitti', 'std4': 'Dolly', 'std5': 'sai'}

# %%
x["std1"]
# Out:
# 'Deepu'

# %%
# x["std3" : "std5"]

# %%
x["std3"] = "chitti🙈"
x
# Out:
# {'std1': 'Deepu',
#  'std2': 'ammu',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly',
#  'std5': 'sai'}

# %%
x["std4"] = "Dolly❤️"
x
# Out:
# {'std1': 'Deepu',
#  'std2': 'ammu',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai'}

# %%
x["std1"] = "Deepu💕"
x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai'}

# %%
x["std2"] = "ammu🩵"
x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai'}

# %%
x.update({"std1_age" : 21})
x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai',
#  'std1_age': 21}

# %%
x.update({"std1_age" : 21})
x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai',
#  'std1_age': 21}

# %%
x.update({"std2_age" : 20, "std3_age" : 21, "std4_age" : 21})

x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai',
#  'std1_age': 21,
#  'std2_age': 20,
#  'std3_age': 21,
#  'std4_age': 21}

# %%
del x["std5"]

x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std1_age': 21,
#  'std2_age': 20,
#  'std3_age': 21,
#  'std4_age': 21}

# %%
x.pop("std1_age")

x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std2_age': 20,
#  'std3_age': 21,
#  'std4_age': 21}

# %%
# x.clear()

# x

# %%
for i in x:
    print(i)
# Out:
# std1
# std2
# std3
# std4
# std2_age
# std3_age
# std4_age

# %%
for i in x.keys():
    print(i)
# Out:
# std1
# std2
# std3
# std4
# std2_age
# std3_age
# std4_age

# %%
for i in x.values():
    print(i)
# Out:
# Deepu💕
# ammu🩵
# chitti🙈
# Dolly❤️
# 20
# 21
# 21

# %%
for i in x:
    print(x[i])
# Out:
# Deepu💕
# ammu🩵
# chitti🙈
# Dolly❤️
# 20
# 21
# 21

# %%
for i in x.items():
    print(i)
# Out:
# ('std1', 'Deepu💕')
# ('std2', 'ammu🩵')
# ('std3', 'chitti🙈')
# ('std4', 'Dolly❤️')
# ('std2_age', 20)
# ('std3_age', 21)
# ('std4_age', 21)

# %%
for i,j in x.items():
    print(i)
# Out:
# std1
# std2
# std3
# std4
# std2_age
# std3_age
# std4_age

# %%
for i,j in x.items():
    print(j)
# Out:
# Deepu💕
# ammu🩵
# chitti🙈
# Dolly❤️
# 20
# 21
# 21

# %%
for i in x:
    x[i] = 123

x
# Out:
# {'std1': 123,
#  'std2': 123,
#  'std3': 123,
#  'std4': 123,
#  'std2_age': 123,
#  'std3_age': 123,
#  'std4_age': 123}

# %%
for i,j in x.items():
    x[i] = 456

x
# Out:
# {'std1': 456,
#  'std2': 456,
#  'std3': 456,
#  'std4': 456,
#  'std2_age': 456,
#  'std3_age': 456,
#  'std4_age': 456}

# %%
x = {'std1' : 'Deepu💕', 'std2' : 'ammu🩵', 'std3' : 'chitti🙈', 'std4' : 'Dolly❤️'}

x
# Out:
# {'std1': 'Deepu💕', 'std2': 'ammu🩵', 'std3': 'chitti🙈', 'std4': 'Dolly❤️'}

# %%
x["std5"] = "sai✌🏻"       # x.update({"std5" : "sai"})

x
# Out:
# {'std1': 'Deepu💕',
#  'std2': 'ammu🩵',
#  'std3': 'chitti🙈',
#  'std4': 'Dolly❤️',
#  'std5': 'sai✌🏻'}

# %%
if "Preetham" in x:
    print(True)
else:
    print(False)
# Out:
# False

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

temp1 = thisdict
temp1["year"] = 2000

print(temp1, thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000} {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

temp2 = thisdict.copy()
temp2["year"] = 2000

print(temp2, thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000} {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %%
myfamily["child1"]["year"]
# Out:
# 2004

# %%
myfamily["child3"]["name"] = "Ammu"

myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Ammu', 'year': 2011}}

# %%
myfamily["child2"] = 123

myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': 123,
#  'child3': {'name': 'Ammu', 'year': 2011}}

# %%
myfamily.pop("child2")

myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child3': {'name': 'Ammu', 'year': 2011}}
