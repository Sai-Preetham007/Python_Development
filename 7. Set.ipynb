# %% [markdown]
# # Declaring set

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
x = {"deepu", "ammu", "dolly", "kitti", "kitti", "ammu"}
print(x)
# Out:
# {'dolly', 'deepu', 'ammu', 'kitti'}

# %%
x = {False, ()}
print(x)
# Out:
# {False, ()}

# %%
y = {bool(False), bool(())}

print(y)
# Out:
# {False}

# %% [markdown]
# # Accessing Set elements

# %%
# thisset[0]

# %%
for i in thisset:
    print(i)
# Out:
# apple
# banana
# cherry

# %%
thisset.add("orange")

print(thisset)
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya", "banana"}

thisset.update(tropical)

print(thisset)
# Out:
# {'apple', 'cherry', 'pineapple', 'banana', 'mango', 'papaya'}

# %%
thisset.update("deepu", "ammu")

print(thisset)
# Out:
# {'apple', 'e', 'papaya', 'u', 'cherry', 'banana', 'a', 'pineapple', 'mango', 'd', 'm', 'p'}

# %%
thisset.remove("a")

print(thisset)
# Out:
# {'apple', 'e', 'papaya', 'u', 'cherry', 'banana', 'pineapple', 'mango', 'd', 'm', 'p'}

# %%
# thisset.remove("sai")

# %%
thisset.discard("e")

print(thisset)
# Out:
# {'apple', 'papaya', 'u', 'cherry', 'banana', 'pineapple', 'mango', 'd', 'm', 'p'}

# %%
thisset.discard("sai")

print(thisset)
# Out:
# {'apple', 'papaya', 'u', 'cherry', 'banana', 'pineapple', 'mango', 'd', 'm', 'p'}

# %%
thisset.pop()

print(thisset)
# Out:
# {'papaya', 'u', 'cherry', 'banana', 'pineapple', 'mango', 'd', 'm', 'p'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)          # set3 = set1 | set2
print(set3)
# Out:
# {'b', 1, 2, 3, 'a', 'c'}

# %%
set1 | set2
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set1
# Out:
# {'a', 'b', 'c'}

# %%
set2
# Out:
# {1, 2, 3}

# %%
set1.update(set2)

# %%
set1
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set2
# Out:
# {1, 2, 3}

# %%
set2.update(set1)

# %%
set1
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set2
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)       # set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 | set2
# Out:
# {'apple', 'banana', 'cherry', 'google', 'microsoft'}

# %%
set1 & set2
# Out:
# {'apple'}

# %%
(set1 | set2) - (set1 & set2)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %% [markdown]
# * BODMAS ---> Bracket, Division, Multiplication, Addition, Substraction

# %%
2 + 3 * 2
# Out:
# 8

# %%
(2 + 3) * 2
# Out:
# 10

# %%
x = {1,2,3}
y = {4,5,6}
z = {"a", "b", "c"}

z.update(x,y)
print(z)
# Out:
# {'b', 1, 2, 3, 4, 5, 6, 'a', 'c'}

# %%
x = {1,2,3}
y = {4,5,6}
z = {"a", "b", "c"}

z = x|y
print(z)
# Out:
# {1, 2, 3, 4, 5, 6}
